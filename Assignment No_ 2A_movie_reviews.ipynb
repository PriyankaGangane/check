# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM
from tensorflow.keras.preprocessing import sequence

# %%
max_words = 10000

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_words)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
max_length = 500

# %%
x_train = sequence.pad_sequences(x_train, maxlen=max_length)
x_test = sequence.pad_sequences(x_test, maxlen=max_length)

# %%
model = Sequential()
model.add(Embedding(max_words, 32, input_length=max_length))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
batch_size = 64
epochs = 5
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 391/391 [==============================] - 484s 1s/step - loss: 0.4142 - accuracy: 0.8066 - val_loss: 0.3613 - val_accuracy: 0.8646
# Epoch 2/5
# 391/391 [==============================] - 458s 1s/step - loss: 0.3699 - accuracy: 0.8468 - val_loss: 0.5294 - val_accuracy: 0.8154
# Epoch 3/5
# 391/391 [==============================] - 477s 1s/step - loss: 0.3210 - accuracy: 0.8744 - val_loss: 0.3726 - val_accuracy: 0.8424
# Epoch 4/5
# 391/391 [==============================] - 476s 1s/step - loss: 0.1987 - accuracy: 0.9262 - val_loss: 0.3466 - val_accuracy: 0.8726
# Epoch 5/5
# 391/391 [==============================] - 479s 1s/step - loss: 0.1531 - accuracy: 0.9459 - val_loss: 0.3572 - val_accuracy: 0.8628

# %%
ss, accuracy = model.evaluate(x_test, y_test)
print("Test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# 782/782 [==============================] - 95s 121ms/step - loss: 0.3572 - accuracy: 0.8628
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-96389ed87e66> in <cell line: 2>()
#       1 ss, accuracy = model.evaluate(x_test, y_test)
# ----> 2 print("Test loss:", loss)
#       3 print("Test accuracy:", accuracy)
#
# NameError: name 'loss' is not defined
